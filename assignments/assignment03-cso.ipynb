# %% [markdown]
# ### Assignment: CSO
#
# Write a program that retrieves the dataset for the "exchequer account (historical series)" from the CSO, and stores it into a file called "cso.json"
#
# ![image.png](attachment:image.png)

# %%
# assignment03-cso
import requests
import json


# URL for the CSO Exchequer Account (Historical Series) dataset
url = "https://ws.cso.ie/public/api.restful/PxStat.Data.Cube_API.ReadDataset/FIQ02/JSON-stat/2.0/en"

response = requests.get(url, verify=False)

# Convert into JSON format
data = response.json()

# Open a file called cso.json and save the dataset into it

with open("cso.json", "w") as f:
    json.dump(data, f, indent=4)

print("Data saved to cso.json")
# Out:
# c:\Users\audreyallen\AppData\Local\anaconda3.2\Lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ws.cso.ie'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Data saved to cso.json

# %% [markdown]
# ### References
#
# https://www.w3schools.com/python/module_requests.asp
#
# https://requests.readthedocs.io/en/latest/user/quickstart/
#
# https://www.w3schools.com/python/python_json.asp
